# %% [markdown]
# <a href="https://colab.research.google.com/github/tahahamdii/Medical-Chatbot-Llama2/blob/main/treatment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Define ranges for input parameters
tumor_locations = ['superficial', 'deep']
ages = np.random.randint(18, 85, size=2000)  # Random ages between 18 and 85
sexes = np.random.choice(['male', 'female'], size=2000)

# Redefine the tumor size categories based on the provided guidelines
tumor_size_values_new = {
    'very_small': (0.1, 0.9),   # Very small tumors: a few millimeters to less than 1 cm
    'medium': (1.0, 5.0),       # Medium tumors: 1 to 5 cm
    'large': (5.1, 10.0),       # Large tumors: more than 5 cm
    'very_large': (10.1, 30.0)  # Very large tumors: several tens of centimeters
}

# Update the function to reflect new tumor size categories
def determine_parameters_with_new_size(tumor_size_cm, location, age, sex):
    # Set base values
    intensity = 0
    frequency = 0
    duration = 0

    # Determine size category
    if tumor_size_cm < 1.0:
        intensity = np.random.uniform(5, 8)
        duration = np.random.uniform(5, 10)
    elif 1.0 <= tumor_size_cm <= 5.0:
        intensity = np.random.uniform(8, 12)
        duration = np.random.uniform(10, 20)
    elif 5.0 < tumor_size_cm <= 10.0:
        intensity = np.random.uniform(12, 16)
        duration = np.random.uniform(20, 30)
    else:
        intensity = np.random.uniform(16, 20)
        duration = np.random.uniform(30, 40)

    # Adjust frequency based on location
    if location == 'superficial':
        frequency = np.random.uniform(1, 3)
    else:  # deep
        frequency = np.random.uniform(0.5, 1)

    # Further adjustments based on age and sex
    if age > 50:
        intensity *= 0.9  # Reduce intensity slightly for older patients
        duration *= 0.9  # Reduce duration slightly for older patients

    if sex == 'male':
        intensity *= 1.1  # Slightly higher intensity for male patients

    return intensity, frequency, duration

# Generate dataset with updated tumor size categories
data_with_new_size_cm = []
for _ in range(2000):
    tumor_size_category = np.random.choice(list(tumor_size_values_new.keys()))
    tumor_size_cm = np.random.uniform(*tumor_size_values_new[tumor_size_category])
    location = np.random.choice(tumor_locations)
    age = np.random.randint(18, 85)
    sex = np.random.choice(['male', 'female'])
    intensity, frequency, duration = determine_parameters_with_new_size(tumor_size_cm, location, age, sex)
    data_with_new_size_cm.append([tumor_size_cm, location, age, sex, intensity, frequency, duration])

# Create DataFrame with new tumor size categories
df_with_new_size_cm = pd.DataFrame(data_with_new_size_cm, columns=['tumor_size_cm', 'tumor_location', 'age', 'sex', 'intensity', 'frequency', 'duration'])

# Mapping tumor locations and sexes to integers
location_map = {'superficial': 0, 'deep': 1}
sex_map = {'male': 0, 'female': 1}

# Apply the mapping to the dataset
df_with_new_size_cm['tumor_location'] = df_with_new_size_cm['tumor_location'].map(location_map)
df_with_new_size_cm['sex'] = df_with_new_size_cm['sex'].map(sex_map)

# Save to CSV
df_with_new_size_cm.to_csv('Ultrasound_Treatment_Parameters_Dataset_Encoded.csv', index=False)

df_with_new_size_cm.head()
# Out:
#    tumor_size_cm  tumor_location  age  sex  intensity  frequency   duration
# 0       2.033987               1   31    0  10.356695   0.544624  16.187023
# 1      27.530040               1   65    1  14.499102   0.776775  32.818988
# 2      16.034069               1   66    0  19.604619   0.684721  34.491453
# 3      11.216021               1   56    1  15.330424   0.742391  32.693242
# 4       3.238718               1   67    1   7.701371   0.541171   9.478668

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset from the CSV file
df = pd.read_csv('Ultrasound_Treatment_Parameters_Dataset_Encoded.csv')

# Split the data into train and test sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42, shuffle=True)

# Extract the input features and target columns
input_features = df.columns[1:-3]  # All columns except the last 3
target_columns = df.columns[-3:]  # The last 3 columns

# Split the data into inputs (X) and targets (y) for training and testing
X_train = train_data[input_features].values
Y_train = train_data[target_columns].values
X_test = test_data[input_features].values
Y_test = test_data[target_columns].values
# Assuming you have already loaded your data into X and Y

# %%
from sklearn.model_selection import RandomizedSearchCV

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Hyperparameter tuning for Random Forest
rf_param_grid = {
    'n_estimators': [50, 100, 200],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Hyperparameter tuning for Gradient Boosting
gb_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

best_rf_models = []
best_gb_models = []

for i in range(Y_train.shape[1]):
    # Random Forest
    rf = RandomForestRegressor(random_state=42)
    rf_random = RandomizedSearchCV(estimator=rf, param_distributions=rf_param_grid, n_iter=100, cv=3, verbose=2, random_state=42, n_jobs=-1)
    rf_random.fit(X_train, Y_train[:, i])
    best_rf = rf_random.best_estimator_
    best_rf_models.append(best_rf)

    # Gradient Boosting
    gb = GradientBoostingRegressor(random_state=42)
    gb_random = RandomizedSearchCV(estimator=gb, param_distributions=gb_param_grid, n_iter=100, cv=3, verbose=2, random_state=42, n_jobs=-1)
    gb_random.fit(X_train, Y_train[:, i])
    best_gb = gb_random.best_estimator_
    best_gb_models.append(best_gb)

# Make predictions with the tuned models
rf_predictions = np.zeros(Y_test.shape)
gb_predictions = np.zeros(Y_test.shape)
rf_mae_list = []
gb_mae_list = []

for i in range(Y_test.shape[1]):
    rf_predictions[:, i] = best_rf_models[i].predict(X_test)
    gb_predictions[:, i] = best_gb_models[i].predict(X_test)
    rf_mae_list.append(mean_absolute_error(Y_test[:, i], rf_predictions[:, i]))
    gb_mae_list.append(mean_absolute_error(Y_test[:, i], gb_predictions[:, i]))

rf_mae_overall = np.mean(rf_mae_list)
gb_mae_overall = np.mean(gb_mae_list)

print(f'Tuned Random Forest Overall MAE: {rf_mae_overall}')
print(f'Tuned Gradient Boosting Overall MAE: {gb_mae_overall}')

# Average predictions for ensemble
ensemble_predictions = (rf_predictions + gb_predictions) / 2
ensemble_mae_list = [mean_absolute_error(Y_test[:, i], ensemble_predictions[:, i]) for i in range(Y_test.shape[1])]
ensemble_mae_overall = np.mean(ensemble_mae_list)
print(f'Ensemble Overall MAE: {ensemble_mae_overall}')
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 120 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [-0.09902271 -0.18962721 -0.18438198         nan         nan -0.10017736
#  -0.23150722 -0.15800925         nan -0.15180499         nan         nan
#  -0.18818424 -0.12003604         nan -0.22714873 -0.10215244 -0.1255835
#          nan         nan -0.14101587 -0.25360681 -0.1075766          nan
#          nan -0.09665633 -0.10616172 -0.10807129 -0.19308806 -0.1075766
#          nan -0.13882681         nan         nan -0.23176088         nan
#  -0.25548443 -0.16010727         nan         nan         nan -0.14411494
#  -0.15799399         nan -0.11340355 -0.16010727         nan -0.1075766
#  -0.23176088         nan -0.1075766  -0.1868932          nan -0.11340355
#  -0.10616172 -0.11340355 -0.18221531         nan         nan -0.14664613
#          nan -0.14417839 -0.16010727         nan         nan -0.1075766
#          nan         nan         nan -0.14664613         nan -0.19308806
#  -0.15504011 -0.10616172 -0.1913893  -0.10807129 -0.13268871         nan
#  -0.11340355         nan -0.2302563  -0.25343685         nan -0.18567562
#  -0.16013987         nan -0.16892232 -0.22714873 -0.1075766          nan
#  -0.18818424 -0.23176088         nan -0.22714873         nan -0.25360681
#          nan -0.19312671         nan         nan]
#   warnings.warn(
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 120 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.65239661 0.63859105 0.63756813        nan        nan 0.65061982
#  0.61612593 0.6373395         nan 0.64441851        nan        nan
#  0.62605619 0.65000766        nan 0.61705796 0.64764761 0.64884577
#         nan        nan 0.64095065 0.61018236 0.64557729        nan
#         nan 0.65088112 0.64610063 0.64757019 0.62496052 0.64557729
#         nan 0.64084683        nan        nan 0.61605434        nan
#  0.61019615 0.63628094        nan        nan        nan 0.64152453
#  0.63732202        nan 0.64530407 0.63628094        nan 0.64557729
#  0.61605434        nan 0.64557729 0.63904998        nan 0.64530407
#  0.64609739 0.64530407 0.62619183        nan        nan 0.64312969
#         nan 0.64166734 0.63628094        nan        nan 0.64557729
#         nan        nan        nan 0.64312969        nan 0.62496052
#  0.63781482 0.64610063 0.62572856 0.64757019 0.64829668        nan
#  0.64530407        nan 0.61789963 0.61028669        nan 0.62643577
#  0.6362601         nan 0.64025833 0.61705796 0.64557729        nan
#  0.62605619 0.61605434        nan 0.61705796        nan 0.61018236
#         nan 0.6247957         nan        nan]
#   warnings.warn(
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 120 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [-0.11502524 -0.20298683 -0.19371788         nan         nan -0.11883617
#  -0.24870199 -0.17530532         nan -0.16913609         nan         nan
#  -0.20437478 -0.13667107         nan -0.24044488 -0.12028267 -0.13901915
#          nan         nan -0.16089002 -0.26832715 -0.12565422         nan
#          nan -0.1147613  -0.1226882  -0.12594654 -0.21026218 -0.12565422
#          nan -0.15728881         nan         nan -0.24878198         nan
#  -0.27143556 -0.17653233         nan         nan         nan -0.16593097
#  -0.1753048          nan -0.13037864 -0.17653233         nan -0.12565422
#  -0.24878198         nan -0.12565422 -0.19658709         nan -0.13037864
#  -0.1226882  -0.13037864 -0.19603613         nan         nan -0.15829996
#          nan -0.16594347 -0.17653233         nan         nan -0.12565422
#          nan         nan         nan -0.15829996         nan -0.21026218
#  -0.17189356 -0.1226882  -0.20797853 -0.12594654 -0.14510932         nan
#  -0.13037864         nan -0.2443337  -0.26807099         nan -0.20169218
#  -0.17659841         nan -0.17942521 -0.24044488 -0.12565422         nan
#  -0.20437478 -0.24878198         nan -0.24044488         nan -0.26832715
#          nan -0.21014476         nan         nan]
#   warnings.warn(
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Tuned Random Forest Overall MAE: 4.439610652317109
# Tuned Gradient Boosting Overall MAE: 4.3441482564041465
# Ensemble Overall MAE: 4.362839348711907

# %%
# Define the ANN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(8, activation='relu'),
    Dense(Y_train.shape[1])
])

# Compile the model with Mean Absolute Error as a metric
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Print the model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, Y_train, epochs=300, batch_size=32, validation_split=0.2 )
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                     │ (None, 64)                  │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,027 (11.82 KB)
#  Trainable params: 3,027 (11.82 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 210.9162 - mean_absolute_error: 10.7732 - val_loss: 190.7628 - val_mean_absolute_error: 9.8124
# Epoch 2/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 159.8921 - mean_absolute_error: 8.6893 - val_loss: 82.5983 - val_mean_absolute_error: 5.6136
# Epoch 3/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.8070 - mean_absolute_error: 5.6320 - val_loss: 51.8328 - val_mean_absolute_error: 4.8020
# Epoch 4/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 56.7732 - mean_absolute_error: 5.2863 - val_loss: 46.4726 - val_mean_absolute_error: 4.6145
# Epoch 5/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.6473 - mean_absolute_error: 4.8425 - val_loss: 45.1992 - val_mean_absolute_error: 4.6006
# Epoch 6/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.8458 - mean_absolute_error: 4.8644 - val_loss: 44.2860 - val_mean_absolute_error: 4.5510
# Epoch 7/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.5719 - mean_absolute_error: 4.9797 - val_loss: 44.1692 - val_mean_absolute_error: 4.5517
# Epoch 8/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.5148 - mean_absolute_error: 4.7190 - val_loss: 43.9182 - val_mean_absolute_error: 4.5414
# Epoch 9/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.4762 - mean_absolute_error: 4.8718 - val_loss: 44.7289 - val_mean_absolute_error: 4.5627
# Epoch 10/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.8120 - mean_absolute_error: 4.8039 - val_loss: 44.2103 - val_mean_absolute_error: 4.5474
# Epoch 11/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.6844 - mean_absolute_error: 4.8362 - val_loss: 44.2319 - val_mean_absolute_error: 4.5391
# Epoch 12/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.1665 - mean_absolute_error: 4.9444 - val_loss: 44.1582 - val_mean_absolute_error: 4.5523
# Epoch 13/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.5396 - mean_absolute_error: 4.6719 - val_loss: 44.5100 - val_mean_absolute_error: 4.5571
# Epoch 14/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.9122 - mean_absolute_error: 4.4806 - val_loss: 43.8446 - val_mean_absolute_error: 4.5319
# Epoch 15/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.9180 - mean_absolute_error: 4.8361 - val_loss: 44.9154 - val_mean_absolute_error: 4.5734
# Epoch 16/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.7015 - mean_absolute_error: 4.7712 - val_loss: 44.1710 - val_mean_absolute_error: 4.5498
# Epoch 17/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.7218 - mean_absolute_error: 4.7380 - val_loss: 43.9379 - val_mean_absolute_error: 4.5478
# Epoch 18/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 47.4815 - mean_absolute_error: 4.6875 - val_loss: 43.7962 - val_mean_absolute_error: 4.5454
# Epoch 19/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.1850 - mean_absolute_error: 4.7400 - val_loss: 43.6651 - val_mean_absolute_error: 4.5532
# Epoch 20/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.6853 - mean_absolute_error: 4.6720 - val_loss: 43.6710 - val_mean_absolute_error: 4.5403
# Epoch 21/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1713 - mean_absolute_error: 4.6718 - val_loss: 43.9564 - val_mean_absolute_error: 4.5585
# Epoch 22/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.5572 - mean_absolute_error: 4.6850 - val_loss: 43.7041 - val_mean_absolute_error: 4.5446
# Epoch 23/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.3672 - mean_absolute_error: 4.8059 - val_loss: 43.8423 - val_mean_absolute_error: 4.5579
# Epoch 24/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.6141 - mean_absolute_error: 4.7252 - val_loss: 44.9300 - val_mean_absolute_error: 4.5938
# Epoch 25/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.6957 - mean_absolute_error: 4.5637 - val_loss: 43.6918 - val_mean_absolute_error: 4.5478
# Epoch 26/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.5944 - mean_absolute_error: 4.8062 - val_loss: 43.5594 - val_mean_absolute_error: 4.5396
# Epoch 27/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.6911 - mean_absolute_error: 4.7082 - val_loss: 43.7309 - val_mean_absolute_error: 4.5449
# Epoch 28/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.0039 - mean_absolute_error: 4.6846 - val_loss: 44.2001 - val_mean_absolute_error: 4.5640
# Epoch 29/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1594 - mean_absolute_error: 4.6468 - val_loss: 44.8319 - val_mean_absolute_error: 4.5797
# Epoch 30/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.7782 - mean_absolute_error: 4.5222 - val_loss: 42.7985 - val_mean_absolute_error: 4.5076
# Epoch 31/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.7569 - mean_absolute_error: 4.6445 - val_loss: 43.7017 - val_mean_absolute_error: 4.5630
# Epoch 32/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.0380 - mean_absolute_error: 4.7537 - val_loss: 43.7865 - val_mean_absolute_error: 4.5531
# Epoch 33/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.9575 - mean_absolute_error: 4.7171 - val_loss: 44.1980 - val_mean_absolute_error: 4.5638
# Epoch 34/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.7249 - mean_absolute_error: 4.6912 - val_loss: 44.6139 - val_mean_absolute_error: 4.5719
# Epoch 35/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.1823 - mean_absolute_error: 4.5584 - val_loss: 44.0240 - val_mean_absolute_error: 4.5591
# Epoch 36/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.6775 - mean_absolute_error: 4.6460 - val_loss: 44.2360 - val_mean_absolute_error: 4.5736
# Epoch 37/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.9674 - mean_absolute_error: 4.6218 - val_loss: 43.7903 - val_mean_absolute_error: 4.5616
# Epoch 38/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.3120 - mean_absolute_error: 4.5599 - val_loss: 44.2055 - val_mean_absolute_error: 4.5820
# Epoch 39/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.7298 - mean_absolute_error: 4.6335 - val_loss: 43.0017 - val_mean_absolute_error: 4.5296
# Epoch 40/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.3804 - mean_absolute_error: 4.6233 - val_loss: 43.8501 - val_mean_absolute_error: 4.5591
# Epoch 41/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.6131 - mean_absolute_error: 4.6856 - val_loss: 44.7558 - val_mean_absolute_error: 4.5859
# Epoch 42/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4040 - mean_absolute_error: 4.5697 - val_loss: 45.0194 - val_mean_absolute_error: 4.5986
# Epoch 43/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2421 - mean_absolute_error: 4.6033 - val_loss: 42.9396 - val_mean_absolute_error: 4.5316
# Epoch 44/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.2094 - mean_absolute_error: 4.5787 - val_loss: 43.3377 - val_mean_absolute_error: 4.5514
# Epoch 45/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.0660 - mean_absolute_error: 4.5499 - val_loss: 43.6117 - val_mean_absolute_error: 4.5493
# Epoch 46/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2771 - mean_absolute_error: 4.6575 - val_loss: 44.7382 - val_mean_absolute_error: 4.5900
# Epoch 47/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.6828 - mean_absolute_error: 4.5684 - val_loss: 42.9840 - val_mean_absolute_error: 4.5344
# Epoch 48/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.4450 - mean_absolute_error: 4.4990 - val_loss: 45.2923 - val_mean_absolute_error: 4.6064
# Epoch 49/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.7848 - mean_absolute_error: 4.4165 - val_loss: 43.4742 - val_mean_absolute_error: 4.5527
# Epoch 50/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4291 - mean_absolute_error: 4.6473 - val_loss: 44.6087 - val_mean_absolute_error: 4.5828
# Epoch 51/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.4549 - mean_absolute_error: 4.5554 - val_loss: 45.4313 - val_mean_absolute_error: 4.6123
# Epoch 52/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2942 - mean_absolute_error: 4.6093 - val_loss: 45.1629 - val_mean_absolute_error: 4.5993
# Epoch 53/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.3185 - mean_absolute_error: 4.5364 - val_loss: 45.3956 - val_mean_absolute_error: 4.6104
# Epoch 54/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.7695 - mean_absolute_error: 4.5481 - val_loss: 44.9546 - val_mean_absolute_error: 4.5982
# Epoch 55/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.4514 - mean_absolute_error: 4.5421 - val_loss: 44.8256 - val_mean_absolute_error: 4.6028
# Epoch 56/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.9805 - mean_absolute_error: 4.2920 - val_loss: 44.0619 - val_mean_absolute_error: 4.5792
# Epoch 57/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.8978 - mean_absolute_error: 4.5755 - val_loss: 44.9027 - val_mean_absolute_error: 4.6020
# Epoch 58/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.5659 - mean_absolute_error: 4.5863 - val_loss: 44.2999 - val_mean_absolute_error: 4.5798
# Epoch 59/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.2948 - mean_absolute_error: 4.5038 - val_loss: 45.2905 - val_mean_absolute_error: 4.6097
# Epoch 60/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.8459 - mean_absolute_error: 4.5800 - val_loss: 43.7273 - val_mean_absolute_error: 4.5660
# Epoch 61/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.5309 - mean_absolute_error: 4.5001 - val_loss: 44.6907 - val_mean_absolute_error: 4.6022
# Epoch 62/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.3643 - mean_absolute_error: 4.4507 - val_loss: 44.8560 - val_mean_absolute_error: 4.6036
# Epoch 63/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.9304 - mean_absolute_error: 4.5113 - val_loss: 44.6111 - val_mean_absolute_error: 4.5832
# Epoch 64/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.0498 - mean_absolute_error: 4.6891 - val_loss: 44.9405 - val_mean_absolute_error: 4.6072
# Epoch 65/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.6774 - mean_absolute_error: 4.5301 - val_loss: 45.4161 - val_mean_absolute_error: 4.6128
# Epoch 66/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.9921 - mean_absolute_error: 4.4421 - val_loss: 43.6484 - val_mean_absolute_error: 4.5559
# Epoch 67/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.7898 - mean_absolute_error: 4.5353 - val_loss: 43.2649 - val_mean_absolute_error: 4.5455
# Epoch 68/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.4218 - mean_absolute_error: 4.6494 - val_loss: 43.8619 - val_mean_absolute_error: 4.5731
# Epoch 69/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.4864 - mean_absolute_error: 4.4768 - val_loss: 43.6425 - val_mean_absolute_error: 4.5708
# Epoch 70/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.5123 - mean_absolute_error: 4.4891 - val_loss: 43.4628 - val_mean_absolute_error: 4.5647
# Epoch 71/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.9190 - mean_absolute_error: 4.4874 - val_loss: 43.7425 - val_mean_absolute_error: 4.5684
# Epoch 72/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.8637 - mean_absolute_error: 4.3349 - val_loss: 44.1426 - val_mean_absolute_error: 4.5812
# Epoch 73/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.0888 - mean_absolute_error: 4.4576 - val_loss: 43.1511 - val_mean_absolute_error: 4.5471
# Epoch 74/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.8890 - mean_absolute_error: 4.4376 - val_loss: 43.4475 - val_mean_absolute_error: 4.5590
# Epoch 75/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.5282 - mean_absolute_error: 4.4882 - val_loss: 45.1485 - val_mean_absolute_error: 4.6021
# Epoch 76/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.9986 - mean_absolute_error: 4.5245 - val_loss: 46.4630 - val_mean_absolute_error: 4.6562
# Epoch 77/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.4783 - mean_absolute_error: 4.4492 - val_loss: 43.8671 - val_mean_absolute_error: 4.5702
# Epoch 78/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.7035 - mean_absolute_error: 4.3957 - val_loss: 43.9891 - val_mean_absolute_error: 4.5736
# Epoch 79/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.5908 - mean_absolute_error: 4.3932 - val_loss: 44.3305 - val_mean_absolute_error: 4.5769
# Epoch 80/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.1004 - mean_absolute_error: 4.6113 - val_loss: 45.4132 - val_mean_absolute_error: 4.6131
# Epoch 81/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 43.2389 - mean_absolute_error: 4.5007 - val_loss: 45.1491 - val_mean_absolute_error: 4.5991
# Epoch 82/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.8025 - mean_absolute_error: 4.5910 - val_loss: 44.5129 - val_mean_absolute_error: 4.5915
# Epoch 83/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.4677 - mean_absolute_error: 4.5485 - val_loss: 44.5268 - val_mean_absolute_error: 4.5921
# Epoch 84/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.4957 - mean_absolute_error: 4.4599 - val_loss: 45.5999 - val_mean_absolute_error: 4.6179
# Epoch 85/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.5846 - mean_absolute_error: 4.5240 - val_loss: 45.4890 - val_mean_absolute_error: 4.6090
# Epoch 86/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.5136 - mean_absolute_error: 4.4032 - val_loss: 44.1963 - val_mean_absolute_error: 4.5809
# Epoch 87/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.5240 - mean_absolute_error: 4.4407 - val_loss: 44.2876 - val_mean_absolute_error: 4.5776
# Epoch 88/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1349 - mean_absolute_error: 4.6531 - val_loss: 44.7472 - val_mean_absolute_error: 4.5953
# Epoch 89/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.5396 - mean_absolute_error: 4.5887 - val_loss: 45.0954 - val_mean_absolute_error: 4.6116
# Epoch 90/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.3290 - mean_absolute_error: 4.5435 - val_loss: 45.4519 - val_mean_absolute_error: 4.6146
# Epoch 91/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.0377 - mean_absolute_error: 4.5628 - val_loss: 44.7418 - val_mean_absolute_error: 4.5959
# Epoch 92/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.2211 - mean_absolute_error: 4.4799 - val_loss: 43.9830 - val_mean_absolute_error: 4.5686
# Epoch 93/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8865 - mean_absolute_error: 4.4275 - val_loss: 45.0416 - val_mean_absolute_error: 4.6069
# Epoch 94/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6287 - mean_absolute_error: 4.3427 - val_loss: 44.1070 - val_mean_absolute_error: 4.5760
# Epoch 95/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.1276 - mean_absolute_error: 4.4677 - val_loss: 45.6047 - val_mean_absolute_error: 4.6229
# Epoch 96/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.7601 - mean_absolute_error: 4.4792 - val_loss: 44.7284 - val_mean_absolute_error: 4.6000
# Epoch 97/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.8494 - mean_absolute_error: 4.3904 - val_loss: 45.4465 - val_mean_absolute_error: 4.6178
# Epoch 98/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.8831 - mean_absolute_error: 4.5678 - val_loss: 44.7503 - val_mean_absolute_error: 4.6014
# Epoch 99/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.5065 - mean_absolute_error: 4.4207 - val_loss: 44.3187 - val_mean_absolute_error: 4.5897
# Epoch 100/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.5383 - mean_absolute_error: 4.3414 - val_loss: 44.4682 - val_mean_absolute_error: 4.5926
# Epoch 101/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.0900 - mean_absolute_error: 4.4474 - val_loss: 45.0265 - val_mean_absolute_error: 4.6081
# Epoch 102/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.9123 - mean_absolute_error: 4.5054 - val_loss: 44.6518 - val_mean_absolute_error: 4.6074
# Epoch 103/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.4862 - mean_absolute_error: 4.4709 - val_loss: 45.3691 - val_mean_absolute_error: 4.6222
# Epoch 104/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0366 - mean_absolute_error: 4.4419 - val_loss: 44.7749 - val_mean_absolute_error: 4.6054
# Epoch 105/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.5167 - mean_absolute_error: 4.4414 - val_loss: 47.4708 - val_mean_absolute_error: 4.6814
# Epoch 106/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8815 - mean_absolute_error: 4.4271 - val_loss: 44.4976 - val_mean_absolute_error: 4.5882
# Epoch 107/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.5562 - mean_absolute_error: 4.5369 - val_loss: 45.2941 - val_mean_absolute_error: 4.6152
# Epoch 108/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.3227 - mean_absolute_error: 4.4634 - val_loss: 45.5433 - val_mean_absolute_error: 4.6231
# Epoch 109/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.9098 - mean_absolute_error: 4.4069 - val_loss: 44.1965 - val_mean_absolute_error: 4.5752
# Epoch 110/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.9443 - mean_absolute_error: 4.5109 - val_loss: 44.2596 - val_mean_absolute_error: 4.5799
# Epoch 111/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.4553 - mean_absolute_error: 4.3666 - val_loss: 46.1969 - val_mean_absolute_error: 4.6437
# Epoch 112/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.3209 - mean_absolute_error: 4.5268 - val_loss: 45.5887 - val_mean_absolute_error: 4.6177
# Epoch 113/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.1875 - mean_absolute_error: 4.3611 - val_loss: 45.4216 - val_mean_absolute_error: 4.6121
# Epoch 114/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.1753 - mean_absolute_error: 4.4832 - val_loss: 43.8047 - val_mean_absolute_error: 4.5542
# Epoch 115/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.4884 - mean_absolute_error: 4.3385 - val_loss: 44.6326 - val_mean_absolute_error: 4.5838
# Epoch 116/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.3747 - mean_absolute_error: 4.4369 - val_loss: 43.5635 - val_mean_absolute_error: 4.5555
# Epoch 117/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.4333 - mean_absolute_error: 4.4792 - val_loss: 44.9342 - val_mean_absolute_error: 4.5921
# Epoch 118/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.8725 - mean_absolute_error: 4.3938 - val_loss: 45.3266 - val_mean_absolute_error: 4.6066
# Epoch 119/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.4875 - mean_absolute_error: 4.2133 - val_loss: 45.8242 - val_mean_absolute_error: 4.6177
# Epoch 120/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.0327 - mean_absolute_error: 4.3838 - val_loss: 45.3313 - val_mean_absolute_error: 4.6147
# Epoch 121/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3414 - mean_absolute_error: 4.4006 - val_loss: 43.1743 - val_mean_absolute_error: 4.5414
# Epoch 122/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.1641 - mean_absolute_error: 4.4090 - val_loss: 46.0759 - val_mean_absolute_error: 4.6208
# Epoch 123/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0196 - mean_absolute_error: 4.4116 - val_loss: 44.2834 - val_mean_absolute_error: 4.5725
# Epoch 124/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.0015 - mean_absolute_error: 4.4813 - val_loss: 45.5045 - val_mean_absolute_error: 4.6079
# Epoch 125/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.5933 - mean_absolute_error: 4.3391 - val_loss: 45.6517 - val_mean_absolute_error: 4.6211
# Epoch 126/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7743 - mean_absolute_error: 4.3488 - val_loss: 44.1189 - val_mean_absolute_error: 4.5711
# Epoch 127/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.8963 - mean_absolute_error: 4.3998 - val_loss: 44.9243 - val_mean_absolute_error: 4.5963
# Epoch 128/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7228 - mean_absolute_error: 4.3343 - val_loss: 45.7029 - val_mean_absolute_error: 4.6207
# Epoch 129/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.4390 - mean_absolute_error: 4.4956 - val_loss: 45.6673 - val_mean_absolute_error: 4.6170
# Epoch 130/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.5987 - mean_absolute_error: 4.3372 - val_loss: 46.0749 - val_mean_absolute_error: 4.6285
# Epoch 131/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.9529 - mean_absolute_error: 4.3646 - val_loss: 45.0406 - val_mean_absolute_error: 4.6022
# Epoch 132/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.1059 - mean_absolute_error: 4.4162 - val_loss: 45.8915 - val_mean_absolute_error: 4.6222
# Epoch 133/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.6312 - mean_absolute_error: 4.4599 - val_loss: 44.6339 - val_mean_absolute_error: 4.5845
# Epoch 134/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.6472 - mean_absolute_error: 4.4536 - val_loss: 43.9623 - val_mean_absolute_error: 4.5633
# Epoch 135/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.2930 - mean_absolute_error: 4.5014 - val_loss: 45.3477 - val_mean_absolute_error: 4.6096
# Epoch 136/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2023 - mean_absolute_error: 4.3281 - val_loss: 45.8507 - val_mean_absolute_error: 4.6173
# Epoch 137/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.4858 - mean_absolute_error: 4.4358 - val_loss: 45.7496 - val_mean_absolute_error: 4.6191
# Epoch 138/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.5830 - mean_absolute_error: 4.3533 - val_loss: 44.4335 - val_mean_absolute_error: 4.5807
# Epoch 139/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.7760 - mean_absolute_error: 4.4262 - val_loss: 45.1747 - val_mean_absolute_error: 4.6027
# Epoch 140/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.5946 - mean_absolute_error: 4.3742 - val_loss: 46.0076 - val_mean_absolute_error: 4.6302
# Epoch 141/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.4396 - mean_absolute_error: 4.4296 - val_loss: 46.0922 - val_mean_absolute_error: 4.6296
# Epoch 142/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.8200 - mean_absolute_error: 4.2963 - val_loss: 44.3653 - val_mean_absolute_error: 4.5769
# Epoch 143/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.0841 - mean_absolute_error: 4.4525 - val_loss: 44.3383 - val_mean_absolute_error: 4.5834
# Epoch 144/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.9357 - mean_absolute_error: 4.4316 - val_loss: 45.2294 - val_mean_absolute_error: 4.6126
# Epoch 145/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.1536 - mean_absolute_error: 4.4945 - val_loss: 44.8121 - val_mean_absolute_error: 4.5916
# Epoch 146/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.2033 - mean_absolute_error: 4.2989 - val_loss: 45.3035 - val_mean_absolute_error: 4.6080
# Epoch 147/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.7584 - mean_absolute_error: 4.3013 - val_loss: 44.4308 - val_mean_absolute_error: 4.5778
# Epoch 148/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.9436 - mean_absolute_error: 4.4802 - val_loss: 45.5296 - val_mean_absolute_error: 4.6126
# Epoch 149/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.5871 - mean_absolute_error: 4.3830 - val_loss: 44.9959 - val_mean_absolute_error: 4.5956
# Epoch 150/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.4944 - mean_absolute_error: 4.3115 - val_loss: 45.0367 - val_mean_absolute_error: 4.5971
# Epoch 151/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.1669 - mean_absolute_error: 4.4972 - val_loss: 44.9970 - val_mean_absolute_error: 4.5968
# Epoch 152/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.9020 - mean_absolute_error: 4.3945 - val_loss: 45.7073 - val_mean_absolute_error: 4.6162
# Epoch 153/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.7038 - mean_absolute_error: 4.4515 - val_loss: 46.0904 - val_mean_absolute_error: 4.6285
# Epoch 154/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.2175 - mean_absolute_error: 4.3130 - val_loss: 47.4234 - val_mean_absolute_error: 4.6659
# Epoch 155/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.4678 - mean_absolute_error: 4.3763 - val_loss: 46.4584 - val_mean_absolute_error: 4.6375
# Epoch 156/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.2201 - mean_absolute_error: 4.3349 - val_loss: 45.6844 - val_mean_absolute_error: 4.6157
# Epoch 157/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.7643 - mean_absolute_error: 4.4027 - val_loss: 46.6283 - val_mean_absolute_error: 4.6385
# Epoch 158/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2570 - mean_absolute_error: 4.3700 - val_loss: 45.3671 - val_mean_absolute_error: 4.6020
# Epoch 159/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.2259 - mean_absolute_error: 4.4341 - val_loss: 45.0712 - val_mean_absolute_error: 4.5919
# Epoch 160/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.0781 - mean_absolute_error: 4.4680 - val_loss: 46.8776 - val_mean_absolute_error: 4.6489
# Epoch 161/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43.4527 - mean_absolute_error: 4.5518 - val_loss: 45.1813 - val_mean_absolute_error: 4.6002
# Epoch 162/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6308 - mean_absolute_error: 4.4209 - val_loss: 44.1966 - val_mean_absolute_error: 4.5708
# Epoch 163/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3540 - mean_absolute_error: 4.3359 - val_loss: 44.8606 - val_mean_absolute_error: 4.5899
# Epoch 164/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.1969 - mean_absolute_error: 4.4693 - val_loss: 46.1809 - val_mean_absolute_error: 4.6290
# Epoch 165/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.6311 - mean_absolute_error: 4.2624 - val_loss: 45.0061 - val_mean_absolute_error: 4.6021
# Epoch 166/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.2277 - mean_absolute_error: 4.4336 - val_loss: 44.6404 - val_mean_absolute_error: 4.5837
# Epoch 167/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.0810 - mean_absolute_error: 4.4887 - val_loss: 45.9358 - val_mean_absolute_error: 4.6306
# Epoch 168/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.9177 - mean_absolute_error: 4.3599 - val_loss: 44.3936 - val_mean_absolute_error: 4.5825
# Epoch 169/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.2269 - mean_absolute_error: 4.4524 - val_loss: 46.5037 - val_mean_absolute_error: 4.6417
# Epoch 170/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8368 - mean_absolute_error: 4.4820 - val_loss: 44.3920 - val_mean_absolute_error: 4.5835
# Epoch 171/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.5652 - mean_absolute_error: 4.4611 - val_loss: 46.9611 - val_mean_absolute_error: 4.6588
# Epoch 172/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.7545 - mean_absolute_error: 4.3833 - val_loss: 43.6681 - val_mean_absolute_error: 4.5590
# Epoch 173/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.1976 - mean_absolute_error: 4.4171 - val_loss: 45.1935 - val_mean_absolute_error: 4.6036
# Epoch 174/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7489 - mean_absolute_error: 4.3693 - val_loss: 44.3809 - val_mean_absolute_error: 4.5801
# Epoch 175/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.6561 - mean_absolute_error: 4.4868 - val_loss: 44.9258 - val_mean_absolute_error: 4.5926
# Epoch 176/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.1550 - mean_absolute_error: 4.3101 - val_loss: 45.7520 - val_mean_absolute_error: 4.6154
# Epoch 177/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8486 - mean_absolute_error: 4.4483 - val_loss: 45.9940 - val_mean_absolute_error: 4.6231
# Epoch 178/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.7180 - mean_absolute_error: 4.4131 - val_loss: 44.4672 - val_mean_absolute_error: 4.5797
# Epoch 179/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.6970 - mean_absolute_error: 4.5278 - val_loss: 44.9192 - val_mean_absolute_error: 4.5967
# Epoch 180/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.1620 - mean_absolute_error: 4.3313 - val_loss: 44.8727 - val_mean_absolute_error: 4.5912
# Epoch 181/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3910 - mean_absolute_error: 4.3728 - val_loss: 44.4026 - val_mean_absolute_error: 4.5746
# Epoch 182/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.2841 - mean_absolute_error: 4.3323 - val_loss: 44.9013 - val_mean_absolute_error: 4.5949
# Epoch 183/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.7327 - mean_absolute_error: 4.4316 - val_loss: 46.3547 - val_mean_absolute_error: 4.6387
# Epoch 184/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.2481 - mean_absolute_error: 4.3034 - val_loss: 44.8482 - val_mean_absolute_error: 4.5966
# Epoch 185/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.3301 - mean_absolute_error: 4.5095 - val_loss: 44.9012 - val_mean_absolute_error: 4.5952
# Epoch 186/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.1588 - mean_absolute_error: 4.4385 - val_loss: 44.9321 - val_mean_absolute_error: 4.5937
# Epoch 187/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.4287 - mean_absolute_error: 4.3229 - val_loss: 45.8992 - val_mean_absolute_error: 4.6252
# Epoch 188/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6196 - mean_absolute_error: 4.4149 - val_loss: 44.8231 - val_mean_absolute_error: 4.5889
# Epoch 189/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2115 - mean_absolute_error: 4.3758 - val_loss: 44.8263 - val_mean_absolute_error: 4.5919
# Epoch 190/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.5584 - mean_absolute_error: 4.4895 - val_loss: 45.9557 - val_mean_absolute_error: 4.6256
# Epoch 191/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7458 - mean_absolute_error: 4.3455 - val_loss: 45.3081 - val_mean_absolute_error: 4.6027
# Epoch 192/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.1538 - mean_absolute_error: 4.3103 - val_loss: 44.8197 - val_mean_absolute_error: 4.5989
# Epoch 193/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.5595 - mean_absolute_error: 4.2749 - val_loss: 46.4802 - val_mean_absolute_error: 4.6409
# Epoch 194/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.3001 - mean_absolute_error: 4.5053 - val_loss: 46.1006 - val_mean_absolute_error: 4.6326
# Epoch 195/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.5447 - mean_absolute_error: 4.3316 - val_loss: 45.7029 - val_mean_absolute_error: 4.6217
# Epoch 196/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2923 - mean_absolute_error: 4.3857 - val_loss: 45.8255 - val_mean_absolute_error: 4.6252
# Epoch 197/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.8784 - mean_absolute_error: 4.4429 - val_loss: 43.8753 - val_mean_absolute_error: 4.5628
# Epoch 198/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.2117 - mean_absolute_error: 4.3813 - val_loss: 44.4910 - val_mean_absolute_error: 4.5821
# Epoch 199/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.8390 - mean_absolute_error: 4.4714 - val_loss: 44.8206 - val_mean_absolute_error: 4.5868
# Epoch 200/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.6005 - mean_absolute_error: 4.3189 - val_loss: 44.2703 - val_mean_absolute_error: 4.5737
# Epoch 201/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.4117 - mean_absolute_error: 4.4152 - val_loss: 44.1849 - val_mean_absolute_error: 4.5674
# Epoch 202/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.7114 - mean_absolute_error: 4.3786 - val_loss: 44.9116 - val_mean_absolute_error: 4.5928
# Epoch 203/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.8569 - mean_absolute_error: 4.3983 - val_loss: 45.0354 - val_mean_absolute_error: 4.5946
# Epoch 204/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.6893 - mean_absolute_error: 4.3034 - val_loss: 44.6211 - val_mean_absolute_error: 4.5875
# Epoch 205/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.0600 - mean_absolute_error: 4.4042 - val_loss: 45.8490 - val_mean_absolute_error: 4.6236
# Epoch 206/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.4496 - mean_absolute_error: 4.4843 - val_loss: 45.0980 - val_mean_absolute_error: 4.6030
# Epoch 207/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.5878 - mean_absolute_error: 4.4107 - val_loss: 45.5380 - val_mean_absolute_error: 4.6128
# Epoch 208/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.7797 - mean_absolute_error: 4.4851 - val_loss: 43.5484 - val_mean_absolute_error: 4.5479
# Epoch 209/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.6550 - mean_absolute_error: 4.4124 - val_loss: 44.4967 - val_mean_absolute_error: 4.5730
# Epoch 210/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.1684 - mean_absolute_error: 4.3769 - val_loss: 45.5391 - val_mean_absolute_error: 4.6065
# Epoch 211/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.7791 - mean_absolute_error: 4.4293 - val_loss: 46.9377 - val_mean_absolute_error: 4.6460
# Epoch 212/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6934 - mean_absolute_error: 4.3790 - val_loss: 44.7781 - val_mean_absolute_error: 4.5850
# Epoch 213/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8822 - mean_absolute_error: 4.4955 - val_loss: 46.0213 - val_mean_absolute_error: 4.6253
# Epoch 214/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8755 - mean_absolute_error: 4.4964 - val_loss: 46.1404 - val_mean_absolute_error: 4.6315
# Epoch 215/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.2957 - mean_absolute_error: 4.4334 - val_loss: 45.0481 - val_mean_absolute_error: 4.5914
# Epoch 216/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.3189 - mean_absolute_error: 4.3223 - val_loss: 44.5590 - val_mean_absolute_error: 4.5757
# Epoch 217/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.7355 - mean_absolute_error: 4.2894 - val_loss: 44.5325 - val_mean_absolute_error: 4.5773
# Epoch 218/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3634 - mean_absolute_error: 4.3965 - val_loss: 45.8883 - val_mean_absolute_error: 4.6151
# Epoch 219/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.8542 - mean_absolute_error: 4.4018 - val_loss: 44.8872 - val_mean_absolute_error: 4.5852
# Epoch 220/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.9558 - mean_absolute_error: 4.4095 - val_loss: 45.0880 - val_mean_absolute_error: 4.5912
# Epoch 221/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0580 - mean_absolute_error: 4.4431 - val_loss: 45.7404 - val_mean_absolute_error: 4.6133
# Epoch 222/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.7724 - mean_absolute_error: 4.4301 - val_loss: 44.7411 - val_mean_absolute_error: 4.5825
# Epoch 223/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6862 - mean_absolute_error: 4.4657 - val_loss: 45.2479 - val_mean_absolute_error: 4.5935
# Epoch 224/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.0675 - mean_absolute_error: 4.3136 - val_loss: 44.5179 - val_mean_absolute_error: 4.5764
# Epoch 225/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3735 - mean_absolute_error: 4.3885 - val_loss: 45.1377 - val_mean_absolute_error: 4.5963
# Epoch 226/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.6976 - mean_absolute_error: 4.3787 - val_loss: 45.1058 - val_mean_absolute_error: 4.5956
# Epoch 227/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.8806 - mean_absolute_error: 4.3739 - val_loss: 45.0331 - val_mean_absolute_error: 4.5934
# Epoch 228/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.9830 - mean_absolute_error: 4.4102 - val_loss: 45.5960 - val_mean_absolute_error: 4.6061
# Epoch 229/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.9105 - mean_absolute_error: 4.3695 - val_loss: 45.4501 - val_mean_absolute_error: 4.6046
# Epoch 230/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7165 - mean_absolute_error: 4.3472 - val_loss: 45.2958 - val_mean_absolute_error: 4.6001
# Epoch 231/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.2536 - mean_absolute_error: 4.4213 - val_loss: 44.7230 - val_mean_absolute_error: 4.5792
# Epoch 232/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.8364 - mean_absolute_error: 4.4933 - val_loss: 45.4594 - val_mean_absolute_error: 4.5981
# Epoch 233/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.1071 - mean_absolute_error: 4.3573 - val_loss: 44.8249 - val_mean_absolute_error: 4.5787
# Epoch 234/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.5523 - mean_absolute_error: 4.4583 - val_loss: 45.9212 - val_mean_absolute_error: 4.6139
# Epoch 235/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.9900 - mean_absolute_error: 4.4397 - val_loss: 45.9133 - val_mean_absolute_error: 4.6162
# Epoch 236/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6920 - mean_absolute_error: 4.4081 - val_loss: 45.6934 - val_mean_absolute_error: 4.6121
# Epoch 237/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.7314 - mean_absolute_error: 4.3992 - val_loss: 46.3142 - val_mean_absolute_error: 4.6247
# Epoch 238/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.0561 - mean_absolute_error: 4.3483 - val_loss: 45.5023 - val_mean_absolute_error: 4.5980
# Epoch 239/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.0860 - mean_absolute_error: 4.2998 - val_loss: 45.5431 - val_mean_absolute_error: 4.5976
# Epoch 240/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.2493 - mean_absolute_error: 4.4514 - val_loss: 44.9150 - val_mean_absolute_error: 4.5815
# Epoch 241/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.8026 - mean_absolute_error: 4.3716 - val_loss: 45.7203 - val_mean_absolute_error: 4.6015
# Epoch 242/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3365 - mean_absolute_error: 4.4037 - val_loss: 46.3873 - val_mean_absolute_error: 4.6259
# Epoch 243/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.3833 - mean_absolute_error: 4.3218 - val_loss: 45.1708 - val_mean_absolute_error: 4.5941
# Epoch 244/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0639 - mean_absolute_error: 4.4292 - val_loss: 46.8318 - val_mean_absolute_error: 4.6389
# Epoch 245/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0832 - mean_absolute_error: 4.3928 - val_loss: 44.7888 - val_mean_absolute_error: 4.5742
# Epoch 246/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2065 - mean_absolute_error: 4.3765 - val_loss: 45.7471 - val_mean_absolute_error: 4.5999
# Epoch 247/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.8939 - mean_absolute_error: 4.2821 - val_loss: 45.2966 - val_mean_absolute_error: 4.5922
# Epoch 248/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0150 - mean_absolute_error: 4.4099 - val_loss: 46.2906 - val_mean_absolute_error: 4.6156
# Epoch 249/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6276 - mean_absolute_error: 4.3878 - val_loss: 46.1904 - val_mean_absolute_error: 4.6162
# Epoch 250/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.5740 - mean_absolute_error: 4.3544 - val_loss: 46.2954 - val_mean_absolute_error: 4.6279
# Epoch 251/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.2197 - mean_absolute_error: 4.3046 - val_loss: 45.5860 - val_mean_absolute_error: 4.5967
# Epoch 252/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.1486 - mean_absolute_error: 4.5731 - val_loss: 45.7933 - val_mean_absolute_error: 4.6062
# Epoch 253/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.3766 - mean_absolute_error: 4.4026 - val_loss: 45.6153 - val_mean_absolute_error: 4.6064
# Epoch 254/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.7930 - mean_absolute_error: 4.2720 - val_loss: 45.0516 - val_mean_absolute_error: 4.5833
# Epoch 255/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.4301 - mean_absolute_error: 4.3580 - val_loss: 44.7731 - val_mean_absolute_error: 4.5704
# Epoch 256/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.0782 - mean_absolute_error: 4.3067 - val_loss: 45.8675 - val_mean_absolute_error: 4.6086
# Epoch 257/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.3603 - mean_absolute_error: 4.3409 - val_loss: 45.9954 - val_mean_absolute_error: 4.6092
# Epoch 258/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.1784 - mean_absolute_error: 4.3136 - val_loss: 45.7604 - val_mean_absolute_error: 4.6011
# Epoch 259/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.0820 - mean_absolute_error: 4.3645 - val_loss: 44.7020 - val_mean_absolute_error: 4.5707
# Epoch 260/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.8295 - mean_absolute_error: 4.4112 - val_loss: 44.8318 - val_mean_absolute_error: 4.5803
# Epoch 261/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.4238 - mean_absolute_error: 4.3988 - val_loss: 44.6492 - val_mean_absolute_error: 4.5742
# Epoch 262/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.1236 - mean_absolute_error: 4.3810 - val_loss: 44.4996 - val_mean_absolute_error: 4.5593
# Epoch 263/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.6555 - mean_absolute_error: 4.2787 - val_loss: 46.1253 - val_mean_absolute_error: 4.6127
# Epoch 264/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.5970 - mean_absolute_error: 4.2491 - val_loss: 45.9841 - val_mean_absolute_error: 4.6128
# Epoch 265/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 41.9816 - mean_absolute_error: 4.4687 - val_loss: 45.5697 - val_mean_absolute_error: 4.5931
# Epoch 266/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.1069 - mean_absolute_error: 4.3128 - val_loss: 46.0631 - val_mean_absolute_error: 4.6054
# Epoch 267/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.9182 - mean_absolute_error: 4.4113 - val_loss: 45.6263 - val_mean_absolute_error: 4.5946
# Epoch 268/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.8814 - mean_absolute_error: 4.3557 - val_loss: 45.6325 - val_mean_absolute_error: 4.5992
# Epoch 269/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.0970 - mean_absolute_error: 4.3407 - val_loss: 45.5317 - val_mean_absolute_error: 4.5998
# Epoch 270/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.5199 - mean_absolute_error: 4.4121 - val_loss: 44.1687 - val_mean_absolute_error: 4.5578
# Epoch 271/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.0510 - mean_absolute_error: 4.3960 - val_loss: 45.7710 - val_mean_absolute_error: 4.6076
# Epoch 272/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.8837 - mean_absolute_error: 4.2466 - val_loss: 44.6402 - val_mean_absolute_error: 4.5712
# Epoch 273/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.4509 - mean_absolute_error: 4.4661 - val_loss: 44.3381 - val_mean_absolute_error: 4.5639
# Epoch 274/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7905 - mean_absolute_error: 4.3169 - val_loss: 45.1247 - val_mean_absolute_error: 4.5877
# Epoch 275/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.1203 - mean_absolute_error: 4.3082 - val_loss: 44.0825 - val_mean_absolute_error: 4.5545
# Epoch 276/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.5868 - mean_absolute_error: 4.3752 - val_loss: 46.4385 - val_mean_absolute_error: 4.6224
# Epoch 277/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.4085 - mean_absolute_error: 4.4724 - val_loss: 44.3477 - val_mean_absolute_error: 4.5650
# Epoch 278/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.5770 - mean_absolute_error: 4.3694 - val_loss: 45.6172 - val_mean_absolute_error: 4.5920
# Epoch 279/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.8408 - mean_absolute_error: 4.3804 - val_loss: 45.4163 - val_mean_absolute_error: 4.5927
# Epoch 280/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6682 - mean_absolute_error: 4.4231 - val_loss: 45.6227 - val_mean_absolute_error: 4.5945
# Epoch 281/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.4150 - mean_absolute_error: 4.3423 - val_loss: 46.5341 - val_mean_absolute_error: 4.6234
# Epoch 282/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.3034 - mean_absolute_error: 4.2558 - val_loss: 44.9245 - val_mean_absolute_error: 4.5739
# Epoch 283/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.5541 - mean_absolute_error: 4.3271 - val_loss: 45.2124 - val_mean_absolute_error: 4.5810
# Epoch 284/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.9478 - mean_absolute_error: 4.3531 - val_loss: 45.1336 - val_mean_absolute_error: 4.5792
# Epoch 285/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0569 - mean_absolute_error: 4.4266 - val_loss: 45.9649 - val_mean_absolute_error: 4.6079
# Epoch 286/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.3661 - mean_absolute_error: 4.3601 - val_loss: 45.5649 - val_mean_absolute_error: 4.6011
# Epoch 287/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.6477 - mean_absolute_error: 4.2647 - val_loss: 45.9482 - val_mean_absolute_error: 4.6121
# Epoch 288/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6750 - mean_absolute_error: 4.4171 - val_loss: 44.9719 - val_mean_absolute_error: 4.5737
# Epoch 289/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2640 - mean_absolute_error: 4.3850 - val_loss: 45.0009 - val_mean_absolute_error: 4.5867
# Epoch 290/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.3466 - mean_absolute_error: 4.2818 - val_loss: 45.2462 - val_mean_absolute_error: 4.5916
# Epoch 291/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.2857 - mean_absolute_error: 4.2376 - val_loss: 45.0382 - val_mean_absolute_error: 4.5757
# Epoch 292/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6411 - mean_absolute_error: 4.3686 - val_loss: 45.7717 - val_mean_absolute_error: 4.5977
# Epoch 293/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.8206 - mean_absolute_error: 4.3106 - val_loss: 45.5160 - val_mean_absolute_error: 4.5933
# Epoch 294/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.0991 - mean_absolute_error: 4.4637 - val_loss: 45.5317 - val_mean_absolute_error: 4.5887
# Epoch 295/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.1994 - mean_absolute_error: 4.3650 - val_loss: 45.5769 - val_mean_absolute_error: 4.5963
# Epoch 296/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.8820 - mean_absolute_error: 4.3086 - val_loss: 45.1100 - val_mean_absolute_error: 4.5784
# Epoch 297/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.0774 - mean_absolute_error: 4.4412 - val_loss: 45.7200 - val_mean_absolute_error: 4.5956
# Epoch 298/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.5606 - mean_absolute_error: 4.3974 - val_loss: 45.9523 - val_mean_absolute_error: 4.6028
# Epoch 299/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.8029 - mean_absolute_error: 4.2355 - val_loss: 45.0442 - val_mean_absolute_error: 4.5815
# Epoch 300/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.3396 - mean_absolute_error: 4.3112 - val_loss: 45.0084 - val_mean_absolute_error: 4.5771

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2663bf4b1ea5> in <cell line: 9>()
#       7 # Assuming you have already loaded your data into X and Y
#       8 # Split data into training and testing sets
# ----> 9 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
#      10
#      11 # Standardize the data
#
# NameError: name 'X' is not defined
